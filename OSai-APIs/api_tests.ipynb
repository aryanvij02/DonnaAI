# %% [markdown]
# for now:
# * run these cells
# * open xcode project and run
#
#
# current to do:
# * format Query Result so difference in font
# * instead of using variables, store context into external file
# * screenshot OCR aggregation (three second intervals?)
# * fix bug where OCR reads OSai output in SS.
# * add gitignore for API keys
# * possibly use OCR specific for Latex (must run locally though...)

# %%
# !python3 -m venv OSai
# !source OSai/bin/activate
# !pip install -r requirements.txt

# %%
# !flask run
# Out:
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# Xcode
# File
# Edit View Find
# Navigate
# Editor Product Debug
# Integrate
# ye OSai
# main
# * OSai l • My Mac
# 88 |
# <>
# @ Preview Assets.xcassets
# • OSaiApp.swift
# I eye.swift
# @ OSai.xcodeproj
# Sai / OSai / I eye.swift /
# 6 struct AppMenu: View {
# M getGemini(context:body:completion:)
# func getGemini(context:String, body:String, completion: @escaping
# (String) -> Void) {
# 50
# 52
# if (body.utf8.count <= 2) {
# completion("Please give a valid input. Input must be greater
# than 2 characters!")
# return;
# let url = URL(string: "http://127.0.0.1:5000/post")!
# var dataRes = ""
# var request = URLRequest(url: url)
# request. setValue(
# "application/json",
# forHTTPHeaderField: "Content-Type"
# 66
# request.httpMethod = "POST"
# ...
